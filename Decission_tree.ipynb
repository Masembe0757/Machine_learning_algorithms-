# %%
import pandas as pd

# %%
df = pd.read_csv('covid data.csv')
df
# Out:
#         INTUBED  PNEUMONIA  AGE  DIABETES  ASTHMA  CARDIOVASCULAR  OBESITY  \
# 0            97          1   72         2       2               2        1
# 1             1          2   55         1       2               2        2
# 2            97          2   68         1       2               2        2
# 3             2          2   24         2       2               2        2
# 4             2          2   30         2       2               2        2
# ...         ...        ...  ...       ...     ...             ...      ...
# 523506       97          2   40         2       2               2        2
# 523507        2          2   51         2       2               2        2
# 523508       97          2   55         2       2               2        2
# 523509       97          2   28         2       2               2        2
# 523510       97          2   52         2       2               2        2
#
#         TOBACCO  ICU STATUS
# 0             2   97   Died
# 1             2    2   Died
# 2             2   97   Died
# 3             2    2  Cured
# 4             2    2  Cured
# ...         ...  ...    ...
# 523506        2   97  Cured
# 523507        2    2  Cured
# 523508        2   97  Cured
# 523509        2   97  Cured
# 523510        2   97  Cured
#
# [523511 rows x 10 columns]

# %%
#Removing unknown values
for x in df.columns:
    df = df[df[x]!=97]
    df = df[df[x]!=98]
    df= df[df[x] != 99]
df
# Out:
#         INTUBED  PNEUMONIA  AGE  DIABETES  ASTHMA  CARDIOVASCULAR  OBESITY  \
# 1             1          2   55         1       2               2        2
# 3             2          2   24         2       2               2        2
# 4             2          2   30         2       2               2        2
# 8             2          1   59         1       2               2        2
# 16            2          1   45         2       2               2        2
# ...         ...        ...  ...       ...     ...             ...      ...
# 523481        2          1   26         2       2               2        2
# 523484        2          2   64         1       2               2        2
# 523486        2          1   50         1       2               2        1
# 523495        2          2   65         1       2               2        2
# 523507        2          2   51         2       2               2        2
#
#         TOBACCO  ICU STATUS
# 1             2    2   Died
# 3             2    2  Cured
# 4             2    2  Cured
# 8             1    1  Cured
# 16            2    2  Cured
# ...         ...  ...    ...
# 523481        2    2  Cured
# 523484        2    2  Cured
# 523486        2    2  Cured
# 523495        2    2  Cured
# 523507        2    2  Cured
#
# [113054 rows x 10 columns]

# %%
df['STATUS'] = df['STATUS'].apply(lambda x : x.replace('Cured', 'likely to cure').replace('Died','likely to die'))
df
# Out:
#         INTUBED  PNEUMONIA  AGE  DIABETES  ASTHMA  CARDIOVASCULAR  OBESITY  \
# 1             1          2   55         1       2               2        2
# 3             2          2   24         2       2               2        2
# 4             2          2   30         2       2               2        2
# 8             2          1   59         1       2               2        2
# 16            2          1   45         2       2               2        2
# ...         ...        ...  ...       ...     ...             ...      ...
# 523481        2          1   26         2       2               2        2
# 523484        2          2   64         1       2               2        2
# 523486        2          1   50         1       2               2        1
# 523495        2          2   65         1       2               2        2
# 523507        2          2   51         2       2               2        2
#
#         TOBACCO  ICU          STATUS
# 1             2    2   likely to die
# 3             2    2  likely to cure
# 4             2    2  likely to cure
# 8             1    1  likely to cure
# 16            2    2  likely to cure
# ...         ...  ...             ...
# 523481        2    2  likely to cure
# 523484        2    2  likely to cure
# 523486        2    2  likely to cure
# 523495        2    2  likely to cure
# 523507        2    2  likely to cure
#
# [113054 rows x 10 columns]

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
x = df[['INTUBED', 'PNEUMONIA', 'AGE', 'DIABETES', 'ASTHMA', 'CARDIOVASCULAR',
       'OBESITY', 'TOBACCO', 'ICU']]
y = df.STATUS

# %%
from sklearn.model_selection import train_test_split as ttt
X_train,X_test,y_train,y_test = ttt(x,y ,test_size = 0.1,  random_state = 40)

# %%
model.fit(X_train,y_train )
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7304970811958252

# %%
model.predict([[2,2,30,2,2,2,2,2,2]])
# Out:
# /home/cipher/.local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['likely to cure'], dtype=object)

# %%
model.predict([[1,1,100,1,1,1,1,1,1]])
# Out:
# /home/cipher/.local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['likely to cure'], dtype=object)

# %%
model.score(X_train,y_train)
# Out:
# 0.7526732712190903
